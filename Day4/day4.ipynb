# %%
akshay = "cool"
if akshay == "cool":
    print("hell yeah")
# Out:
# Running cells with 'precourse (Python 3.12.14)' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
